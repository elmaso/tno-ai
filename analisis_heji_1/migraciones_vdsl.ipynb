# %% [markdown]
# ## Tu apoyo para hacer una análisis de las causas que originan los errores marcados en amarillo más abajo.
#
# ### Por qué mandamos clientes a migrar VDSL si no están en la tarjeta apropiada?
# ### Por qué están en un equipo diferente a VDSL?

# %%
import pandas as pd

# %%
df_err_migracion = pd.read_csv('REP_VDSL_TELNOR_20170213T.csv')
df_err_migracion.head()
# Out:
#      telefono         concentrador           tbaoequipo  b  r   t   p  \
# 0  6161652491     BCN-SANQUINTIN-5     BCN-SANQUINTIN-5  0  0   3  35
# 1  6161652981     BCN-SANQUINTIN-5     BCN-SANQUINTIN-5  0  0   4  13
# 2  6161653290  BCN-RAULSANCHEZDI-3  BCN-RAULSANCHEZDI-3  1  1  11  23
# 3  6461201015         BCN-CIPRES-3         BCN-CIPRES-3  1  1   3   4
# 4  6461525400      BCN-MANEADERO-3      BCN-MANEADERO-3  1  1   7   8
#
#      PERFIL_ORIGEN     PERFIL_FINAL   PERFIL_MIGRADO    ...     VEL_ACCESO  \
# 0  u_a_12544_640_a  u_a_12544_640_a  u_a_12544_640_a    ...            NaN
# 1  u_a_12544_640_a  u_a_12544_640_a  u_a_12544_640_a    ...            NaN
# 2       u_b_7232_a       u_b_7232_a       u_b_7232_a    ...            NaN
# 3  u_b_12544_640_a  u_b_12544_640_a  u_b_12544_640_a    ...            NaN
# 4  u_b_12544_640_a  u_b_12544_640_a  u_b_12544_640_a    ...            NaN
#
#    VEL_INICIAL  VEL_FINAL  VEL_OFERTA  PRECALIFICACION_VDSL  OC MEDIDOS  \
# ...

# %%
df_err_migracion.tail()
# Out:
#         telefono          concentrador            tbaoequipo  b  r  t   p  \
# 2514  6646843565  BCNSAA00AL00SAA00012  BCNSAA00AL00SAA00012  1  1  4  18
# 2515  6646846154          BCN-OBRERA-4          BCN-OBRERA-4  1  1  5  28
# 2516  6646861414       BCN-HIPODROMO-5       BCN-HIPODROMO-5  1  1  8  40
# 2517  6646878827  BCNSAA00AL00SAA00012  BCNSAA00AL00SAA00012  1  1  2  40
# 2518  6646878577  BCNSAA00AL00SAA00012  BCNSAA00AL00SAA00012  1  1  2  36
#
#          PERFIL_ORIGEN      PERFIL_FINAL    PERFIL_MIGRADO    ...     \
# 2514  v_10M_dpbo_0-1km  v_10M_dpbo_0-1km  v_10M_dpbo_0-1km    ...
# 2515        u_b_9600_a        u_b_9600_a        u_b_9600_a    ...
# 2516   u_b_12544_640_a   u_b_12544_640_a   u_b_12544_640_a    ...
# 2517  v_10M_dpbo_0-1km  v_10M_dpbo_0-1km  v_10M_dpbo_0-1km    ...
# 2518  v_10M_dpbo_0-1km  v_10M_dpbo_0-1km  v_10M_dpbo_0-1km    ...
#
#       VEL_ACCESO  VEL_INICIAL  VEL_FINAL  VEL_OFERTA  PRECALIFICACION_VDSL  \
# ...
